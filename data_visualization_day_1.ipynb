# %% [markdown]
# ######1. load the iris.csv dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### 1. create a bar plot for count the frequency of the three species.

# %%
### code here
data=pd.read_csv("D:\\Innomatics\\Data_visualization\\Data_visualization_day_1\\Iris.csv")
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.countplot(x="Species",data=data)
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# we see the all Species frequency are equal

# %% [markdown]
# ##### 2. Create a pie chart to show the percentage of species.

# %%
### code here
plt.pie([50,50,50],labels=["Iris-Setosa","Iris-Versicolor","Iris-Verginica"],autopct="%0.2f%%",explode=[0,0,0],radius=2)
plt.title("Iris_Species")
plt.show()

# %% [markdown]
# pie chart to show the percentage of species all species percantage have 33.33 %

# %% [markdown]
# ##### 3. Create the joint to all numberical variable for analyze the relationship between two variables and describe their individual distributions on the same plot.

# %%
### code here
sns.jointplot(data=data,x="PetalLengthCm",y="PetalWidthCm",hue="Species")

# %% [markdown]
# ##### 4. Create a scatter plot and take hue = "Species"

# %%
### code here
sns.scatterplot(data=data,x="PetalLengthCm",y="PetalWidthCm",hue="Species")
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %% [markdown]
# we take petal length on X axis and Petal width on Y axis
#
# iris setos is countable its petal lentg is approx 2 and petal widhth is0.7
#
# in these chart but versicoler and verginica is overlape each oher in petal length approx 4.5 to 5.5 between

# %% [markdown]
# ###### 5. Create a Boxplot or Whisker plot as univeriate and bivariate analysis.

# %%
### code here
sns.boxplot(data=data,y="SepalLengthCm",x="Species")
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalLengthCm'>

# %% [markdown]
# we take Sepal Length and species in box plot, In these plot we see the setosa is not ovarlap to others, in iris-virginica one outlier is shown
#  vrsicolor and viginica is ovelaping near 6.2cm sepal lenght

# %% [markdown]
# ###### 6. Create a Strip plot

# %%
### code here
sns.stripplot(data=data,x="PetalLengthCm",y="Species")
plt.show()

# %% [markdown]
# ###### 7. Create a Violin Plot.

# %%
### code here
sns.violinplot(data=data,y="SepalLengthCm",x="Species")
plt.show()

# %% [markdown]
# ##### 8. Create a pair chart.

# %%
### code here
sns.pairplot(data,hue="Species",size=2)
plt.show()

# %% [markdown]
# ##### 9. Create a Heat Map

# %%
### code here
data.corr().round(1)
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Id             1.0            0.7          -0.4            0.9           0.9
# SepalLengthCm  0.7            1.0          -0.1            0.9           0.8
# SepalWidthCm  -0.4           -0.1           1.0           -0.4          -0.4
# PetalLengthCm  0.9            0.9          -0.4            1.0           1.0
# PetalWidthCm   0.9            0.8          -0.4            1.0           1.0

# %%
sns.heatmap(data.corr().round(1),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###### 10. Create a distribution plot for all numerical colomns.

# %%
### code here
sns.distplot(x=data["PetalLengthCm"],hist=False)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# in distrubution plot we see the petal lenth density is very high between 5,6

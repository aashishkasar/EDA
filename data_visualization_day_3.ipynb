# %% [markdown]
# ##### import tips dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

data=pd.read_csv(r"D:\Innomatics\Data_visualization\Data_visualization_day_3\tips.csv")
data.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 121       13.42  1.68  Female     No  Thur   Lunch     2
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3
# 179       34.63  3.55    Male    Yes   Sun  Dinner     2
# 171       15.81  3.16    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3

# %% [markdown]
# ##### 1. Write a Python program to display a bar chart of the total bill of Gender and write the intuition about the plot.

# %%
### code here
data[data['smoker']=='Yes'].min()
# Out:
# total_bill      3.07
# tip              1.0
# sex           Female
# smoker           Yes
# day              Fri
# time          Dinner
# size               1
# dtype: object

# %%
a=data[data['sex']=='Male']['total_bill'].sum()
b=data[data['sex']=='Female']['total_bill'].sum()
plt.bar(['Male','Female'],[x,y])
plt.ylabel('total_bill')
plt.show()

# %% [raw]
# In these Data, we see that Genderwise Male is paid more bill as compared to female

# %% [markdown]
# ###### 2. Write a Python program to display a box plot of the total bill of day and hue = "smoker" and write the intuition about the plot.

# %%
#### code here
sns.boxplot(data=data,y='total_bill',hue='smoker')
plt.show()

# %% [raw]
# There are some off outliers between above 40 to 50 of the total bill

# %% [markdown]
# ##### 3. Write a Python program to display a violin plot of the total bill of Day and hue = "sex" and write the intuition about the plot.

# %%
sns.violinplot(data=data,y='total_bill',x='sex',hue='sex',size=5)
plt.show()

# %% [raw]
# There is lots of male and female bill in the range of 10 to 20,
# there is very few females is paying above 40 and few male is paying above 50

# %% [markdown]
# ##### 4. Write a Python program to display a strip plot of the total bill of Day and hue = "sex" and write the intuition about the plot.

# %%
### code here 
sns.stripplot(data=data,y='total_bill',x='sex')
plt.show()

# %% [raw]
# There is lots of male and female bill in the range of 10 to 20,
# there is just two female paying above 40 and approx 6/7 male is paying above 40

# %% [markdown]
# ##### 5. Write a Python program to display heat map of dataframe and write the intuition about the plot.

# %%
### code here
sns.heatmap(data.corr().round(1),annot=True)
plt.show()

# %% [markdown]
# ##### 6. Write a Python program to display scatter plot of total bill of tip and write the intuition about the plot.

# %%
### code here
sns.scatterplot(data=data,y="total_bill",x="tip",hue="sex")
plt.show()

# %% [raw]
# There is only two male giving tip above 8
# there is lots of male & female is give tip between 1 to 5

# %% [markdown]
# ##### 7. Write a Python program to display density plot of all numerical columns from the dataframe and write the intution about plot.

# %%
### code here
sns.kdeplot(x=data["total_bill"])
plt.show()

# %% [raw]
# In this plot we see a very high density of bills paying btween 10 to 25

# %%
sns.kdeplot(x=data["tip"])
plt.show()

# %%
In these plot, we see a very high density of tips giving between 2 to 3

# %%
sns.kdeplot(x=data["size"])
plt.show()

# %% [markdown]
# ##### 8. Write a Python program to calculate average total bills by days and display top 4 days by plot.

# %%
a
# Out:
# day               Fri        Sat    Sun       Thur
# total_bill  17.151579  20.441379  21.41  17.682742

# %%
### code here
a=data.pivot_table(columns='day',aggfunc=({'total_bill':np.mean}))
sns.barplot(['Fri','Sat','Sun','Thur'],[x['Fri'][0],x['Sat'][0],x['Sun'][0],x['Thur'][0]])
plt.ylabel('avg of total_bill')
plt.show()

# %% [markdown]
# #### Bonus Question

# %% [markdown]
# ###### 1. What is Histogram chart ?

# %% [raw]
# #### write here
#      A histogram is basically used to represent data provided in a form of some groups.It is accurate method for the graphical representation of numerical data distribution.It is a type of bar plot where X-axis represents the bin ranges while Y-axis gives information about frequency.

# %% [markdown]
# ##### 2. What is box plot ?

# %% [raw]
# ### write here
#      A Box Plot is also known as Whisker plot is created to display the summary of the set of data values having properties like minimum, first quartile, median, third quartile and maximum.

# %% [markdown]
# ##### 3. What are the plots we can use for univeriate analysis.

# %% [markdown]
# ### write here
#
# Histograms — sns.histplot() ...
#
# KDE plot — sns.kdeplot() ...
#
# KDE with Histogram plot — sns.histplot(kde=True) ...
#
# Rug plot — sns.rugplot() ...
#
# Box plots — sns.boxplot() ...
#
# Violin plot — sns.violinplot() ...
#
# Strip plot — sns.stripplot()

# %% [markdown]
# ##### 4. What are the plots we can use for bivariate analysis.

# %%
### code here

# %% [markdown]
# ###### 5. What are plot we can use for multivariate analysis.

# %% [raw]
# ### code here
#
# Scatter plot
#
# A scatter plot shows the relationship between two numeric features by using dots to visualize how these variables move together
